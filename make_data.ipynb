# %%
from datasets import load_dataset

ds = load_dataset("aarohanverma/simple-daily-conversations-cleaned", split = 'train')

# %%
type(ds)
# Out:
# datasets.arrow_dataset.Dataset

# %%
ds[0]['data']
# Out:
# 'i usually enjoy the weekends but not this one'

# %%
import os

os.environ["OPENAI_API_KEY"] = "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"

from openai import OpenAI

client_open = OpenAI()

# %%
import os

os.environ["GEMINI_API_KEY"] = "AQ.Ab8RN6I13XNclLFyTEXVbftPSGV_Ijauyo0s0TAZpZ2b0UibQw"
from google import genai

client_gem = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

# %%
response = client.responses.create(
    model="gpt-5.6-luna",
    input="""
Translate each English sentence into natural, casual, conversational Hindi.

Rules:
- Each numbered line is one separate sentence.
- Translate every sentence.
- Do not skip, merge, split, reorder, or combine sentences.
- Preserve the exact meaning.
- Use everyday spoken Hindi.
- College-student / young-adult conversational Hindi is preferred.
- Use a slightly Hinglish tone where natural, but keep Hindi as the primary language.
- Avoid formal, literary, or textbook Hindi.
- Do not add information.
- Keep names, numbers, brands, titles, and technical terms unchanged.
- Preserve the original English sentence exactly.
- Return the same numbering.
- Return ONLY the translations in TSV format.

OUTPUT FORMAT:
Each output line MUST contain exactly three fields separated by a TAB character:

[number]    [original English sentence]    [Hindi translation]

Example:

Input:
1. How are you?
2. What are you doing?

Output:
1	How are you?	तुम कैसे हो?
2	What are you doing?	तुम क्या कर रहे हो?

IMPORTANT:
- The first field must be the original number.
- The second field must be the EXACT original English string.
- The third field must contain ONLY the Hindi translation.
- Do not modify, paraphrase, translate, or correct the English string.
- Do not put tabs inside any field.
- Do not add a header.
- Do not add Markdown.
- Do not use code fences.
- Do not add explanations or comments.
- Output exactly one line for every input sentence.

Before returning the answer, silently verify that:
1. The number of output lines equals the number of input lines.
2. Every original English string is preserved exactly.
3. Every line contains exactly two TAB characters.
4. Every line has a Hindi translation.
5. The numbering and order are unchanged.

English:
{text}
"""
)

print(response.output_text)
# Out:
# मैंने तो अभी-अभी खुद चार डोनट खा लिए।

# %%
def translate_text_open(text):
    response = client_open.responses.create(
        model="gpt-5.6-luna",
        input=f"""
Translate each English sentence into natural, casual, conversational Hindi.

Rules:
- Each numbered line is one separate sentence.
- Translate every sentence.
- Do not skip, merge, split, reorder, or combine sentences.
- Preserve the exact meaning.
- Use everyday spoken Hindi.
- College-student / young-adult conversational Hindi is preferred.
- Use a slightly Hinglish tone where natural, but keep Hindi as the primary language.
- Avoid formal, literary, or textbook Hindi.
- Do not add information.
- Keep names, numbers, brands, titles, and technical terms unchanged.
- Preserve the original English sentence exactly.
- Return the same numbering.
- Return ONLY the translations in TSV format.

OUTPUT FORMAT:
Each output line MUST contain exactly three fields separated by a TAB character:

[number]    [original English sentence]    [Hindi translation]

Example:

Input:
1. How are you?
2. What are you doing?

Output:
1	How are you?	तुम कैसे हो?
2	What are you doing?	तुम क्या कर रहे हो?

IMPORTANT:
- The first field must be the original number.
- The second field must be the EXACT original English string.
- The third field must contain ONLY the Hindi translation.
- Do not modify, paraphrase, translate, or correct the English string.
- Do not put tabs inside any field.
- Do not add a header.
- Do not add Markdown.
- Do not use code fences.
- Do not add explanations or comments.
- Output exactly one line for every input sentence.

Before returning the answer, silently verify that:
1. The number of output lines equals the number of input lines.
2. Every original English string is preserved exactly.
3. Every line contains exactly two TAB characters.
4. Every line has a Hindi translation.
5. The numbering and order are unchanged.

English:
{text}
"""
    )

    return response.output_text.strip()


#translate_text("you can always get yourself another dog")

# %%
def translate_text_gem(text):
    response = client_gem.models.generate_content(
        model="gemini-3.6-flash",
        contents=f"""
Translate each English sentence into natural, casual,
conversational Hindi.

Rules:
- Each numbered line is one separate sentence.
- Translate every sentence.
- Do not skip, merge, or split sentences.
- Preserve the exact meaning.
- Use everyday spoken Hindi.
- College-student / young-adult conversational Hindi is preferred.
- Avoid formal or literary Hindi.
- Do not add information.
- Keep names, numbers, and technical terms unchanged.
- Return the same numbering.
- Return ONLY the translations.
- return original string and 

Example:

Input:
1. How are you?
2. What are you doing?

Output:
1\tHow are you?\tतुम कैसे हो?
2\tWhat are you doing?\tक्या कर रहे हो?

English:
{text}
"""
    )

    return response.text.strip()

#translate_text("you can always get yourself another dog")

# %%
import time 

start = time.perf_counter()

batch = ""
batchsize = 50
for i in range(50,100):
    batch+=f"{i+1}. {ds[i]['data']}\n"
    
print(translate_text_open(batch))

end = time.perf_counter()

print("time taken(s): ", (end-start))
# Out:
# 51	life is unpredicatable and on the road it is not how you drive it is how other drive	ज़िंदगी अनिश्चित होती है, और सड़क पर मायने यह नहीं रखता कि तुम कैसे गाड़ी चलाते हो, बल्कि यह कि दूसरे कैसे चलाते हैं।
# 52	are you going to run errands or just chill	तुम काम निपटाने जा रहे हो या बस chill करोगे?
# 53	well the game does not come out until october	खैर, game अक्टूबर तक रिलीज़ नहीं होगा।
# 54	it is much more than what i had at that age	यह उस उम्र में मेरे पास जितना था, उससे कहीं ज़्यादा है।
# 55	it really hurt when my dad died randomly	जब मेरे डैड की अचानक मौत हो गई, तो मुझे बहुत बुरा लगा।
# 56	yes but i try not to compare	हाँ, लेकिन मैं तुलना करने से बचने की कोशिश करता हूँ।
# 57	oh well hopefully you learned some kind of lesson from this and it will not happen again	ओह, खैर, उम्मीद है तुमने इससे किसी तरह का सबक सीखा होगा और ऐसा दोबारा नहीं होगा।
# 58	have you made an appointment with your doctor	क्या तुमने अपने डॉक्टर से appointment लिया है?
# ...

# %%
import time 

start = time.perf_counter()

batch = ""
batchsize = 50
for i in range(50,100):
    batch+=f"{i+1}. {ds[i]['data']}\n"

content = translate_text_gem(batch)
print(content)

end = time.perf_counter()

print("time taken(s): ", (end-start))

try:
    with open("en_hi.tsv", "w", encoding="utf-8") as file:
        file.write(content)
    print("Data written successfully!")
except Exception as e:
    print("Error writing file:", e)
# Out:
# 51	life is unpredicatable and on the road it is not how you drive it is how other drive	लाइफ का कुछ भरोसा नहीं है, और रोड पर यह मायने नहीं रखता कि तुम कैसे ड्राइव करते हो, बल्कि यह कि दूसरे कैसे ड्राइव करते हैं।
# 52	are you going to run errands or just chill	तुम कुछ काम से जा रहे हो या बस चिल करने?
# 53	well the game does not come out until october	वैसे, गेम अक्टूबर तक नहीं आ रहा है।
# 54	it is much more than what i had at that age	उस उम्र में मेरे पास जितना था, यह उससे कहीं ज़्यादा है।
# 55	it really hurt when my dad died randomly	जब मेरे पापा अचानक चले गए, तो मुझे बहुत दुख हुआ था।
# 56	yes but i try not to compare	हाँ, पर मैं तुलना न करने की कोशिश करता हूँ।
# 57	oh well hopefully you learned some kind of lesson from this and it will not happen again	खैर, उम्मीद है तुमने इससे कोई सबक सीखा होगा और यह दोबारा नहीं होगा।
# 58	have you made an appointment with your doctor	क्या तुमने डॉक्टर से अपॉइंटमेंट ले लिया?
# ...

# %%
print(batch)
# Out:
# 51. life is unpredicatable and on the road it is not how you drive it is how other drive
# 52. are you going to run errands or just chill
# 53. well the game does not come out until october
# 54. it is much more than what i had at that age
# 55. it really hurt when my dad died randomly
# 56. yes but i try not to compare
# 57. oh well hopefully you learned some kind of lesson from this and it will not happen again
# 58. have you made an appointment with your doctor
# 59. i actually plan to keep it he has not noticed yet
# 60. it can really be annoying when someone tells you what to do
# 61. i have been trying to get a job with this company for years
# 62. i took in a small kitten i found and have been nursing her back to health
# 63. it is best to remember these things every now and then
# 64. they serve authentic mexican food
# 65. oh my that is along time
# 66. it is hard to change habits sometimes
# 67. that is true well there is a lot of time left
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\RBI\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
import sys
# !{sys.executable} -m pip install -U google-genai

# %%
# !{sys.executable} -m pip install -U openai

# %%
import pandas as pd

df = pd.read_csv("en_hi.tsv", delimiter = '\t')

df.columns = ['id', 'en', 'hi']

# %%
df
# Out:
#      id                                                 en  \
# 0    52         are you going to run errands or just chill
# 1    53      well the game does not come out until october
# 2    54        it is much more than what i had at that age
# 3    55           it really hurt when my dad died randomly
# 4    56                       yes but i try not to compare
# 5    57  oh well hopefully you learned some kind of les...
# 6    58      have you made an appointment with your doctor
# 7    59  i actually plan to keep it he has not noticed yet
# 8    60  it can really be annoying when someone tells y...
# 9    61  i have been trying to get a job with this comp...
# 10   62  i took in a small kitten i found and have been...
# 11   63  it is best to remember these things every now ...
# 12   64                  they serve authentic mexican food
# 13   65                           oh my that is along time
# 14   66              it is hard to change habits sometimes
# ...

# %%
###########  GOING TO A TSV

import time 

start = time.perf_counter()

batch = ""
batchsize = 50
for i in range(50,100):
    batch+=f"{i+1}. {ds[i]['data']}\n"

content = translate_text_open(batch)
print(content)

end = time.perf_counter()

print("time taken(s): ", (end-start))

lines = content.splitlines()

for line in lines:
    parts = line.split("\t")

    if len(parts) != 3:
        raise ValueError(f"Bad TSV line: {line}")

    number, english, hindi = parts

    if not hindi.strip():
        raise ValueError(f"Empty translation: {line}")

# Only append AFTER every line passes validation
with open("en_hindi.tsv", "a", encoding="utf-8") as f:
    for line in lines:
        f.write(line + "\n")

try:
    with open("en_hi.tsv", "w", encoding="utf-8") as file:
        file.write(content)
    print("Data written successfully!")
except Exception as e:
    print("Error writing file:", e)

# %%
def translate_write_tsv(batch):
    translations = translate_text_open(batch)

    lines = translations.splitlines()

    for line in lines:
        parts = line.split("\t")
    
        if len(parts) != 3:
            raise ValueError(f"Bad TSV line: {line}")
    
        number, english, hindi = parts
    
        if not hindi.strip():
            raise ValueError(f"Empty translation: {line}")
    
    # Only append AFTER every line passes validation
    with open("en_hindi.tsv", "a", encoding="utf-8") as f:
        for line in lines:
            f.write(line + "\n")
    
    try:
        with open("en_hi.tsv", "w", encoding="utf-8") as file:
            file.write(content)
        print("Data written successfully!")
    except Exception as e:
        print("Error writing file:", e)

# %%
## main course

def translate_write_tsv(batch):
    translations = translate_text_open(batch)

    lines = translations.splitlines()

    for line in lines:
        parts = line.split("\t")
    
        if len(parts) != 3:
            raise ValueError(f"Bad TSV line: {line}")
    
        number, english, hindi = parts
    
        if not hindi.strip():
            raise ValueError(f"Empty translation: {line}")
    
    # Only append AFTER every line passes validation
    with open("en_hindi.tsv", "a", encoding="utf-8") as f:
        for line in lines:
            f.write(line + "\n")
    

#NOW MAKING BATCH ADDER
j = 1

batch = ""
step = 100
for i in range(0, 30000, step):
    batch_ = ""
    for c in ds[i:i+step]['data']:
        batch_+=f"{j} {c}\n"
        j+=1

    #batch created now ask for
    translate_write_tsv(batch_)
    print(f"{j / 300:.2f}% completed-------------------------")

print (batch)
# Out:
# 0.34% completed-------------------------
# 0.67% completed-------------------------
# 1.00% completed-------------------------
# 1.34% completed-------------------------
# 1.67% completed-------------------------
# 2.00% completed-------------------------
# 2.34% completed-------------------------
# 2.67% completed-------------------------
# 3.00% completed-------------------------
# 3.34% completed-------------------------
# 3.67% completed-------------------------
# 4.00% completed-------------------------
# 4.34% completed-------------------------
# 4.67% completed-------------------------
# 5.00% completed-------------------------
# 5.34% completed-------------------------
# 5.67% completed-------------------------
# 6.00% completed-------------------------
# 6.34% completed-------------------------
# 6.67% completed-------------------------
# 7.00% completed-------------------------
# 7.34% completed-------------------------
# 7.67% completed-------------------------
# ...

# %%
for line in ds[0:59]['data']:
    print(line)
# Out:
# i usually enjoy the weekends but not this one
# we tried to scare them away but they almost attacked me
# i was nervous for no reason
# have you tried to look into other providers to see if there is a better deal available
# i do not need anything else in life
# you can always get yourself another dog
# i was the one who was being seduced as the married man
# i have to call my landlord about being late on the rent
# i cannot elieve my daughter is starting highschool
# the game was full of intrigue
# university is starting up soon and i am nervous
# nice i love watching cute dogs doing cool things
# why what is happening on monday
# i have not practiced enough
# some of my daughters classmates in prek have been crying since the first day of school
# yes but it took us a few minutes to do so because we were so shocked
# i did one of those water coasters the other day
# i just ate four donuts myself
# i rehearsed all night for my speech
# ...

# %%
import pandas as pd

df = pd.read_csv('en_hindi.tsv', delimiter = '\t')

# %%
df
# Out:
#            1      i usually enjoy the weekends but not this one  \
# 0          2   we tried to scare them away but they almost a...
# 1          3                        i was nervous for no reason
# 2          4   have you tried to look into other providers t...
# 3          5                i do not need anything else in life
# 4          6            you can always get yourself another dog
# ...      ...                                                ...
# 30194  29996                     if all goes well it can happen
# 30195  29997                    oh it happens to the best of us
# 30196  29998  you never know unless you ask and it never hur...
# 30197  29999  yes it was turned out it was just my dog sneak...
# 30198  30000  i have no clue he just sort of made a suggesti...
#
#       मुझे आमतौर पर वीकेंड्स पसंद होते हैं, लेकिन ये वाला नहीं।
# 0      हमने उन्हें डराकर भगाने की कोशिश की, लेकिन उन्...
# 1                         मैं बिना किसी वजह के नर्वस था।
# ...

# %%
df.tail()
# Out:
#            1      i usually enjoy the weekends but not this one  \
# 30194  29996                     if all goes well it can happen
# 30195  29997                    oh it happens to the best of us
# 30196  29998  you never know unless you ask and it never hur...
# 30197  29999  yes it was turned out it was just my dog sneak...
# 30198  30000  i have no clue he just sort of made a suggesti...
#
#       मुझे आमतौर पर वीकेंड्स पसंद होते हैं, लेकिन ये वाला नहीं।
# 30194                  अगर सब ठीक रहा, तो यह हो सकता है।
# 30195  ओह, ऐसा हममें से सबसे अच्छे लोगों के साथ भी हो...
# 30196  जब तक पूछोगे नहीं, तब तक पता नहीं चलेगा, और पू...
# 30197  हाँ, ऐसा ही था—पता चला कि मेरा dog चुपके से co...
# 30198  मुझे बिल्कुल पता नहीं, उसने बस इस बारे में मेर...

# %%
df.isnull()
# Out:
#            1   i usually enjoy the weekends but not this one  \
# 0      False                                           False
# 1      False                                           False
# 2      False                                           False
# 3      False                                           False
# 4      False                                           False
# ...      ...                                             ...
# 30194  False                                           False
# 30195  False                                           False
# 30196  False                                           False
# 30197  False                                           False
# 30198  False                                           False
#
#        मुझे आमतौर पर वीकेंड्स पसंद होते हैं, लेकिन ये वाला नहीं।
# 0                                                  False
# 1                                                  False
# ...

# %%
df.isna().sum()
# Out:
# 1                                                            0
#  i usually enjoy the weekends but not this one               0
# मुझे आमतौर पर वीकेंड्स पसंद होते हैं, लेकिन ये वाला नहीं।    0
# dtype: int64

# %%
df[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.tail(1)
# Out:
#            1      i usually enjoy the weekends but not this one  \
# 30198  30000  i have no clue he just sort of made a suggesti...
#
#       मुझे आमतौर पर वीकेंड्स पसंद होते हैं, लेकिन ये वाला नहीं।
# 30198  मुझे बिल्कुल पता नहीं, उसने बस इस बारे में मेर...

# %%
df1 = df.tail(1)

# %%
df1
# Out:
#            1      i usually enjoy the weekends but not this one  \
# 30198  30000  i have no clue he just sort of made a suggesti...
#
#       मुझे आमतौर पर वीकेंड्स पसंद होते हैं, लेकिन ये वाला नहीं।
# 30198  मुझे बिल्कुल पता नहीं, उसने बस इस बारे में मेर...

# %%
df1.reset_index()
# Out:
#    index      1      i usually enjoy the weekends but not this one  \
# 0  30198  30000  i have no clue he just sort of made a suggesti...
#
#   मुझे आमतौर पर वीकेंड्स पसंद होते हैं, लेकिन ये वाला नहीं।
# 0  मुझे बिल्कुल पता नहीं, उसने बस इस बारे में मेर...

# %%
df1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[:]
# Out:
#            1      i usually enjoy the weekends but not this one  \
# 0          2   we tried to scare them away but they almost a...
# 1          3                        i was nervous for no reason
# 2          4   have you tried to look into other providers t...
# 3          5                i do not need anything else in life
# 4          6            you can always get yourself another dog
# ...      ...                                                ...
# 30194  29996                     if all goes well it can happen
# 30195  29997                    oh it happens to the best of us
# 30196  29998  you never know unless you ask and it never hur...
# 30197  29999  yes it was turned out it was just my dog sneak...
# 30198  30000  i have no clue he just sort of made a suggesti...
#
#       मुझे आमतौर पर वीकेंड्स पसंद होते हैं, लेकिन ये वाला नहीं।
# 0      हमने उन्हें डराकर भगाने की कोशिश की, लेकिन उन्...
# 1                         मैं बिना किसी वजह के नर्वस था।
# ...
